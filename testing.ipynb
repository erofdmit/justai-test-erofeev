# %% [markdown]
# Установка зависимостей

# %%
# !pip install requests scikit-learn nerus numpy pandas
# Out:
# Requirement already satisfied: requests in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (2.32.3)
# Requirement already satisfied: scikit-learn in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (1.5.1)
# Requirement already satisfied: nerus in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (2.1.1)
# Requirement already satisfied: pandas in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from requests) (2024.6.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\thjat\.pyenv\pyenv-win\versions\3.12.3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Основные константы

# %%
import os

PATH = '.'
PREDICT_URL = 'https://caila.io/api/mlpgate/account/1000167571/model/90066/predict'
REQUEST_PATTERN = {
  "service": "",
  "model": "",
  "text": ""
}
HEADER = {
            "MLP-API-KEY": os.getenv('MLP_API_KEY'),
            "Content-Type": "application/json"
}

# %% [markdown]
# Оценки f1, recall, precision

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

def evaluate_model(predictions, ground_truths):
    y_true = [1 if entity in gt else 0 for gt in ground_truths for entity in predictions]
    y_pred = [1 if entity in predictions else 0 for gt in ground_truths for entity in predictions]

    precision = precision_score(y_true, y_pred, zero_division=1)
    recall = recall_score(y_true, y_pred, zero_division=1)
    f1 = f1_score(y_true, y_pred, zero_division=1)

    return precision, recall, f1

# %% [markdown]
# Оценка скорости работы

# %%
import time

def measure_speed(predict_function, data):
    start_time = time.time()
    result = predict_function(data)
    end_time = time.time()
    processing_time = end_time - start_time
    return processing_time, result

# %% [markdown]
# Создание реквеста

# %%
def create_request_payload(service: str, model: str, text: str) -> dict:
    request = REQUEST_PATTERN.copy()
    request['service'] = service
    request['model'] = model
    request['text'] = text
    return request

# %% [markdown]
# Запрос на сервис

# %%
import requests

import json

def predict_function(service: str, model: str, text: str):
    print(service, model, text)
    payload = create_request_payload(service, model, text)
    response = requests.post(url=PREDICT_URL, json=payload, headers=HEADER)
    print(response)
    response_data = response.json()
    entities = json.loads(response_data.get('response', '[]')) 
    return entities

# %% [markdown]
# Работа с csv

# %%
import csv
from typing import List, Dict, Tuple

def extract_per_entities(doc):
    text, spans = doc.ner
    return [text[span.start:span.stop] for span in spans if span.type == 'PER']

def count_tokens(text: str) -> int:
    # Простейшая оценка: количество слов
    return len(text.split())

def save_to_csv(text: str, ground_truth: List[str], predictions_per_model: Dict[str, List[str]]):
    rows = []
    # Собираем данные для каждой модели
    for model, predictions in predictions_per_model.items():
        row = [text, ', '.join(ground_truth), model, ', '.join(predictions)]
        rows.append(row)

    # Записываем в CSV файл
    with open('results.csv', 'a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file, delimiter='|')
        writer.writerows(rows)

# %% [markdown]
# Основной скрипт теста

# %%
def run_evaluation(docs: List, services_and_models: List[Dict], num_docs=10) -> Tuple[List[Dict], List[Dict]]:
    metrics = []
    speed_data = []
    
    processed_count = 0  # Счетчик обработанных документов
    
    for doc in docs:
        if processed_count >= num_docs:
            break
        
        ground_truth = extract_per_entities(doc)
        
        if not ground_truth or len(doc.ner.text) > 1000:
            continue
        
        # Подсчёт токенов
        token_count = count_tokens(doc.ner.text)
        
        predictions_per_model = {}
        
        for service_model in services_and_models:
            service = service_model['service']
            model = service_model['model']
            text = doc.ner.text
            
            # Замеряем время обработки и получаем предсказания
            try:
                processing_time, predictions = measure_speed(lambda x: predict_function(service, model, x), text)
                predictions_per_model[model] = predictions

                # Оцениваем модель
                precision, recall, f1 = evaluate_model(predictions, ground_truth)
                metrics.append({
                    'service': service, 
                    'model': model, 
                    'precision': precision, 
                    'recall': recall, 
                    'f1': f1
                })
                
                speed_data.append({
                    'service': service, 
                    'model': model, 
                    'processing_time': processing_time,
                    'input_tokens': token_count,  # Добавляем количество токенов для входных данных
                    'output_tokens': token_count  # Предположим, что выходные токены равны входным (если это не так, исправьте соответствующим образом)
                })

            except Exception as e:
                print(f"Error with service {service} and model {model}: {e}")

        # Сохраняем результаты в CSV
        save_to_csv(doc.ner.text, ground_truth, predictions_per_model)
        
        processed_count += 1  # Увеличиваем счетчик обработанных документов
    
    return metrics, speed_data

# %% [markdown]
# Список моделей

# %%
services_and_models = [
    {"service": "openai-proxy", "model": "gpt-4o-mini", "input_cost": 0.02, "output_cost": 0.1},
    {"service": "yandexgpt", "model": "yandexgpt-lite/latest", "input_cost": 0.2, "output_cost": 0.2},
]

# %% [markdown]
# Старт основного расчета

# %%
from nerus import load_nerus

nerus_path = os.path.join(PATH, "nerus_lenta.conllu.gz")
docs = load_nerus(nerus_path)

metrics, speed_data = run_evaluation(docs, services_and_models)
# Out:
# 1725565419.384989
# openai-proxy gpt-4o-mini Вице-премьер по социальным вопросам Татьяна Голикова рассказала, в каких регионах России зафиксирована наиболее высокая смертность от рака, сообщает РИА Новости. По словам Голиковой, чаще всего онкологические заболевания становились причиной смерти в Псковской, Тверской, Тульской и Орловской областях, а также в Севастополе. Вице-премьер напомнила, что главные факторы смертности в России — рак и болезни системы кровообращения. В начале года стало известно, что смертность от онкологических заболеваний среди россиян снизилась впервые за три года. По данным Росстата, в 2017 году от рака умерли 289 тысяч человек. Это на 3,5 процента меньше, чем годом ранее.
# <Response [200]>
# ['Голикова Татьяна']
# 1725565421.1273727
# 1725565421.133221
# <Response [200]>
# ['Макрон']
# 1725565448.248385
# 1725565448.2563689
# yandexgpt yandexgpt-lite/latest Протесты движения «желтых жилетов» в Париже снова привели к столкновениям с полицией, пустившей в ход слезоточивый газ. Об этом в субботу, 15 декабря, сообщает The Daily Mail. Демонстрация проходила рядом с Оперой Гарнье в центре французской столицы. Протестующие прорвали полицейский кордон, стали переворачивать мусорные контейнеры и, распевая «Марсельезу», требовать отставки президента страны Эммануэля Макрона. Полиция в ответ пустила слезоточивый газ и открыла огонь резиновыми пулями по «желтым жилетам». Более 60 человек было арестовано. Беспорядки во Франции продолжаются с середины октября. Недовольство жителей страны вызвала новость о повышении налога на бензин.
# <Response [200]>
# ['Эммануэль Макрон']
# 1725565449.5526104
# 1725565449.5632834
# openai-proxy gpt-4o-mini Истребитель Су-27 разбился в Житомирской области Украины, сообщает пресс-служба Генерального штаба Вооруженных сил Украины (ВСУ). «Летчик погиб. Обстоятельства и причины происшествия выясняются», — говорится в сообщении. Отмечается, что катастрофа произошла при заходе на посадку. Истребитель выполнял плановый полет. 16 октября в Винницкой области Украины на учениях Clear Sky 2018 разбился еще один истребитель Су-27. В результате аварии погибли два пилота — военный летчик I класса Иван Петренко и военнослужащий воздушных сил Национальной гвардии США. Позже выяснилось, что машина была непригодна для полетов.
# <Response [200]>
# ['Иван Петренко']
# 1725565451.3143682
# 1725565451.3240058
# yandexgpt yandexgpt-lite/latest Истребитель Су-27 разбился в Житомирской области Украины, сообщает пресс-служба Генерального штаба Вооруженных сил Украины (ВСУ). «Летчик погиб. Обстоятельства и причины происшествия выясняются», — говорится в сообщении. Отмечается, что катастрофа произошла при заходе на посадку. Истребитель выполнял плановый полет. 16 октября в Винницкой области Украины на учениях Clear Sky 2018 разбился еще один истребитель Су-27. В результате аварии погибли два пилота — военный летчик I класса Иван Петренко и военнослужащий воздушных сил Национальной гвардии США. Позже выяснилось, что машина была непригодна для полетов.
# <Response [200]>
# Error with service yandexgpt and model yandexgpt-lite/latest: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# Подсчет метрик

# %%
import pandas as pd
from typing import List, Dict

# Функция для расчёта стоимости
def calculate_cost(speed_data: List[Dict], services_and_models: List[Dict]) -> pd.DataFrame:
    cost_df = pd.DataFrame(services_and_models)
    speed_df = pd.DataFrame(speed_data)

    # Объединение данных о скорости и метриках
    merged_df = pd.merge(speed_df, cost_df, on=['service', 'model'])

    # Рассчёт стоимости
    merged_df['cost'] = (
        merged_df['input_tokens'] * merged_df['input_cost'] + 
        merged_df['output_tokens'] * merged_df['output_cost']
    )

    return merged_df

# Создаём DataFrame из данных
metrics_df = pd.DataFrame(metrics)
speed_df = pd.DataFrame(speed_data)
# Объединяем данные о скорости и метриках
metrics_avg = metrics_df.groupby(['service', 'model']).mean().reset_index()
speed_avg = speed_df.groupby(['service', 'model']).mean().reset_index()
# Переименовываем столбцы перед объединением для избежания конфликтов
speed_avg = speed_avg.rename(columns={
    'processing_time': 'speed_processing_time',
    'input_tokens': 'speed_input_tokens',
    'output_tokens': 'speed_output_tokens'
})

# Объединение с данными о стоимости
costs_df = calculate_cost(speed_data, services_and_models)
merged_df = pd.merge(speed_avg, metrics_avg, on=['service', 'model'])
merged_df = pd.merge(merged_df, costs_df, on=['service', 'model'])

# Поиск лучших моделей по каждой метрике
best_precision = merged_df.loc[merged_df['precision'].idxmax()]
best_recall = merged_df.loc[merged_df['recall'].idxmax()]
best_f1 = merged_df.loc[merged_df['f1'].idxmax()]

# Вывод лучших моделей по каждой метрике
print(f"Best Model for Precision: \n{best_precision}")
print(f"Best Model for Recall: \n{best_recall}")
print(f"Best Model for F1 Score: \n{best_f1}")

# Вывод стоимости работы
print("\nCost of Processing:")
print(merged_df[['service', 'model', 'cost']])

# Дополнительно, вывод средних значений по метрикам и скорости
print("\nAverage Metrics and Speed:")
print(merged_df)
# Out:
# Best Model for Precision:
# service                  openai-proxy
# model                     gpt-4o-mini
# speed_processing_time        1.942026
# speed_input_tokens               99.6
# speed_output_tokens              99.6
# precision                    0.491667
# recall                            1.0
# f1                           0.565238
# processing_time              1.742384
# input_tokens                       92
# output_tokens                      92
# input_cost                       0.02
# output_cost                       0.1
# cost                            11.04
# Name: 0, dtype: object
# Best Model for Recall:
# service                  openai-proxy
# model                     gpt-4o-mini
# speed_processing_time        1.942026
# speed_input_tokens               99.6
# speed_output_tokens              99.6
# precision                    0.491667
# recall                            1.0
# f1                           0.565238
# processing_time              1.742384
# input_tokens                       92
# output_tokens                      92
# input_cost                       0.02
# output_cost                       0.1
# cost                            11.04
# Name: 0, dtype: object
# Best Model for F1 Score:
# service                  openai-proxy
# model                     gpt-4o-mini
# speed_processing_time        1.942026
# speed_input_tokens               99.6
# speed_output_tokens              99.6
# precision                    0.491667
# recall                            1.0
# f1                           0.565238
# processing_time              1.742384
# input_tokens                       92
# output_tokens                      92
# input_cost                       0.02
# output_cost                       0.1
# cost                            11.04
# Name: 0, dtype: object
#
# Cost of Processing:
#          service                  model   cost
# 0   openai-proxy            gpt-4o-mini  11.04
# 1   openai-proxy            gpt-4o-mini  10.32
# 2   openai-proxy            gpt-4o-mini  15.60
# 3   openai-proxy            gpt-4o-mini  12.24
# 4   openai-proxy            gpt-4o-mini   8.04
# 5   openai-proxy            gpt-4o-mini  16.44
# 6   openai-proxy            gpt-4o-mini   9.84
# 7   openai-proxy            gpt-4o-mini  15.36
# 8   openai-proxy            gpt-4o-mini  10.80
# 9   openai-proxy            gpt-4o-mini   9.84
# 10     yandexgpt  yandexgpt-lite/latest  36.80
# 11     yandexgpt  yandexgpt-lite/latest  34.40
# 12     yandexgpt  yandexgpt-lite/latest  52.00
# 13     yandexgpt  yandexgpt-lite/latest  26.80
# 14     yandexgpt  yandexgpt-lite/latest  54.80
# 15     yandexgpt  yandexgpt-lite/latest  32.80
# 16     yandexgpt  yandexgpt-lite/latest  51.20
# 17     yandexgpt  yandexgpt-lite/latest  36.00
#
# Average Metrics and Speed:
#          service                  model  speed_processing_time  \
# 0   openai-proxy            gpt-4o-mini               1.942026
# 1   openai-proxy            gpt-4o-mini               1.942026
# 2   openai-proxy            gpt-4o-mini               1.942026
# 3   openai-proxy            gpt-4o-mini               1.942026
# 4   openai-proxy            gpt-4o-mini               1.942026
# 5   openai-proxy            gpt-4o-mini               1.942026
# 6   openai-proxy            gpt-4o-mini               1.942026
# 7   openai-proxy            gpt-4o-mini               1.942026
# 8   openai-proxy            gpt-4o-mini               1.942026
# 9   openai-proxy            gpt-4o-mini               1.942026
# 10     yandexgpt  yandexgpt-lite/latest               1.364160
# 11     yandexgpt  yandexgpt-lite/latest               1.364160
# 12     yandexgpt  yandexgpt-lite/latest               1.364160
# 13     yandexgpt  yandexgpt-lite/latest               1.364160
# 14     yandexgpt  yandexgpt-lite/latest               1.364160
# 15     yandexgpt  yandexgpt-lite/latest               1.364160
# 16     yandexgpt  yandexgpt-lite/latest               1.364160
# 17     yandexgpt  yandexgpt-lite/latest               1.364160
#
#     speed_input_tokens  speed_output_tokens  precision  recall        f1  \
# 0                 99.6                 99.6   0.491667     1.0  0.565238
# 1                 99.6                 99.6   0.491667     1.0  0.565238
# 2                 99.6                 99.6   0.491667     1.0  0.565238
# 3                 99.6                 99.6   0.491667     1.0  0.565238
# 4                 99.6                 99.6   0.491667     1.0  0.565238
# 5                 99.6                 99.6   0.491667     1.0  0.565238
# 6                 99.6                 99.6   0.491667     1.0  0.565238
# 7                 99.6                 99.6   0.491667     1.0  0.565238
# 8                 99.6                 99.6   0.491667     1.0  0.565238
# 9                 99.6                 99.6   0.491667     1.0  0.565238
# 10               101.5                101.5   0.187500     1.0  0.250000
# 11               101.5                101.5   0.187500     1.0  0.250000
# 12               101.5                101.5   0.187500     1.0  0.250000
# 13               101.5                101.5   0.187500     1.0  0.250000
# 14               101.5                101.5   0.187500     1.0  0.250000
# 15               101.5                101.5   0.187500     1.0  0.250000
# 16               101.5                101.5   0.187500     1.0  0.250000
# 17               101.5                101.5   0.187500     1.0  0.250000
#
#     processing_time  input_tokens  output_tokens  input_cost  output_cost  \
# 0          1.742384            92             92        0.02          0.1
# 1          1.802100            86             86        0.02          0.1
# 2          2.472983           130            130        0.02          0.1
# 3          2.685562           102            102        0.02          0.1
# 4          1.639410            67             67        0.02          0.1
# 5          1.782978           137            137        0.02          0.1
# 6          1.621670            82             82        0.02          0.1
# 7          2.372195           128            128        0.02          0.1
# 8          1.549892            90             90        0.02          0.1
# 9          1.751085            82             82        0.02          0.1
# 10         1.246658            92             92        0.20          0.2
# 11         1.299713            86             86        0.20          0.2
# 12         1.357604           130            130        0.20          0.2
# 13         1.377502            67             67        0.20          0.2
# 14         1.263083           137            137        0.20          0.2
# 15         1.318677            82             82        0.20          0.2
# 16         1.753805           128            128        0.20          0.2
# 17         1.296242            90             90        0.20          0.2
#
#      cost
# 0   11.04
# 1   10.32
# 2   15.60
# 3   12.24
# 4    8.04
# 5   16.44
# 6    9.84
# 7   15.36
# 8   10.80
# 9    9.84
# 10  36.80
# 11  34.40
# 12  52.00
# 13  26.80
# 14  54.80
# 15  32.80
# 16  51.20
# 17  36.00
